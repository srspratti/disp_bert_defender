# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from google.colab import drive
import os
drive.mount('/content/drive/', force_remount = True)
ROOT_PATH="/content/drive/My Drive/Udem/Winter2021/IFT 6756 - Game Theory and ML/Term Project"
os.chdir(ROOT_PATH)
os.getcwd()
src_path = "./disp_bert_defender"
os.listdir(src_path)
os.chdir(src_path)
# Out:
# Mounted at /content/drive/

# %%
import torch
torch.cuda.is_available()
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# True
# '/device:GPU:0'

# %%
# !pip install torch
# !which python
# !pip install boto3
# !pip install hnswlib==0.5.1
# !pip install sklearn
# !pip install pandas
# !pip install nltk
import nltk
nltk.download('punkt')
# Out:
# ...
# /usr/local/bin/python
# ...
#      |████████████████████████████████| 133kB 8.5MB/s
# ...
#      |████████████████████████████████| 81kB 9.1MB/s
# ...
#      |████████████████████████████████| 7.4MB 15.8MB/s
# ...
#      |████████████████████████████████| 153kB 49.2MB/s
# ...
# ERROR: requests 2.23.0 has requirement urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you'll have urllib3 1.26.4 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ...
#   Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for hnswlib: filename=hnswlib-0.5.1-cp37-cp37m-linux_x86_64.whl size=1296758 sha256=8153f4a88edb9d4ab82785a7426a3b7cf2e43d02246058a1f512315e53673f88
# ...

# %%
# !pip install dynet
# !pip install allennlp
# Out:
# [autoreload of urllib3.connectionpool failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
# ImportError: cannot import name 'BrokenPipeError' from 'urllib3.connection' (/usr/local/lib/python3.7/dist-packages/urllib3/connection.py)
# ]
# [autoreload of urllib3.packages.six failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
# AttributeError: 'NoneType' object has no attribute 'cStringIO'
# ]
# [autoreload of urllib3.connection failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
# ...

# %%
# !pip install urllib3
# !pip install chardet

# !pip3 install requests
# !pip3 install folium
# Out:
# [autoreload of urllib3.packages.six failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
# AttributeError: 'NoneType' object has no attribute 'cStringIO'
# ]
# [autoreload of urllib3.util failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
# ImportError: cannot import name 'PROTOCOL_TLS' from 'urllib3.util.ssl_' (/usr/local/lib/python3.7/dist-packages/urllib3/util/ssl_.py)
# ]
# ...

# %%
num_disc_epochs = 5
num_disc_epochs_eval = num_disc_epochs - 1 
folder  = "./data/sst-2/"
folder_disc  = "./data/sst-2/grd_disc"

word_embedding_file = "../emb/wiki-news-300d-1M-s.vec"
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# [dynet] random seed: 42
# [dynet] allocating memory: 512MB
# [dynet] memory allocation done.
# usage: GAN2vec_RobGAN_train.py [-h] --sample SAMPLE --data_dir DATA_DIR
#                                --task_name TASK_NAME --output_dir OUTPUT_DIR
#                                [--word_embedding_file WORD_EMBEDDING_FILE]
#                                [--index_path INDEX_PATH]
#                                [--word_embedding_info WORD_EMBEDDING_INFO]
#                                [--data_file DATA_FILE] [--cache_dir CACHE_DIR]
#                                [--do_lower_case]
#                                [--max_seq_length MAX_SEQ_LENGTH]
#                                [--max_ngram_length MAX_NGRAM_LENGTH]
#                                [--do_train] [--do_eval]
#                                [--train_batch_size TRAIN_BATCH_SIZE]
# ...

# %%
# %%bash
# python GAN2vec_RobGAN_train.py \
# --task_name sst-2 \
# --do_train \
# --do_lower_case \
# --data_dir $folder_disc \
# --bert_model bert-base-uncased \
# --max_seq_length 128 \
# --train_batch_size 8 \
# --learning_rate 2e-5 \
# --num_train_epochs $num_disc_epochs \
# --output_dir $folder_disc \
# --word_embedding_file $word_embedding_file \
# --verbose
# # --no_cuda
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# [dynet] random seed: 42
# [dynet] allocating memory: 512MB
# [dynet] memory allocation done.
# usage: GAN2vec_RobGAN_train.py [-h] --sample SAMPLE --data_dir DATA_DIR
#                                --task_name TASK_NAME --output_dir OUTPUT_DIR
#                                [--word_embedding_file WORD_EMBEDDING_FILE]
#                                [--index_path INDEX_PATH]
#                                [--word_embedding_info WORD_EMBEDDING_INFO]
#                                [--data_file DATA_FILE] [--cache_dir CACHE_DIR]
#                                [--do_lower_case]
#                                [--max_seq_length MAX_SEQ_LENGTH]
#                                [--max_ngram_length MAX_NGRAM_LENGTH]
#                                [--do_train] [--do_eval]
#                                [--train_batch_size TRAIN_BATCH_SIZE]
# ...
